# %% [markdown]
# # Kamindu's Data Analysis
#
# With a contentious and tight US Presidential Election coming up on November 5th 2024, the objective of this analysis is to gain insights in to the US presidential elections over the years.
#
# ### Document
# <b>Author:</b> Sahan Fernando<br>
# <b>Title:</b> Kamindu's Data Analysis <br>
#
# ### Data source
#
# <b>Author:</b> Sahan Fernando<br>
# <b>Title:</b> Kamindu's test performances dataset<br>
# <b>Description: </b>Compiled scorecard information of all tests that Kamindu Mendis has played since his debut on 8th July 2022 to his purple patch performances in 2024

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import the data set

# %%
df = pd.read_csv("kamindu_test_dataset.csv")
df.head()
# Out:
#    batting_position                  batter      mode_of_dismissal  score  \
# 0               1.0        Pathum Nissanka         c Green b Starc    6.0
# 1               2.0  Dimuth Karunaratne (c)          lbw b Swepson   86.0
# 2               3.0           Kusal Mendis              lbw b Lyon   85.0
# 3               4.0         Angelo Mathews   c Labuschagne b Starc   52.0
# 4               5.0       Dinesh Chandimal                 not out  206.0
#
#    balls  minutes  fours  sixes  strike_rate  team_innings_total  innings  \
# 0   25.0     38.0    0.0    0.0        24.00                 554        2
# 1  165.0    246.0   10.0    0.0        52.12                 554        2
# 2  161.0    253.0    9.0    0.0        52.79                 554        2
# 3  117.0    163.0    4.0    0.0        44.44                 554        2
# 4  326.0    545.0   16.0    5.0        63.19                 554        2
#
#   opposition  venue host_country    date  year sl_result  test_no
# ...
